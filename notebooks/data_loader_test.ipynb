# %%
import pandas as pd
from src.common.utils import get_root_directory

# %%
root_dir = get_root_directory()
sentiment_data = pd.read_csv(f"{root_dir}/data/final/sentiment_analysis.csv", index_col="Date", parse_dates=True)

# %%
sentiment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 156574 entries, 2017-11-09 to 2024-08-11
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   News Headline          156574 non-null  object
#  1   Publisher              156574 non-null  object
#  2   D_VADER_Score          156574 non-null  float64
#  3   D_VADER_Sent           156574 non-null  int64
#  4   D_FINBERT_ConScore     156574 non-null  float64
#  5   D_FINBERT_Sent         156574 non-null  int64
#  6   D_CRYPTOBERT_ConScore  156574 non-null  float64
#  7   D_CRYPTOBERT_Sent      156574 non-null  int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.8+ MB

# %%
from src.preprocessing.feature_generator import FeatureGenerator

# %%
FG = FeatureGenerator(input_data=sentiment_data, data_tag="sentiment")

# %%
final_data = FG.generate_features()
# Out:
#              Date                                      News Headline  \
# 0      2017-11-09  Hong Kong Fintech Innovation Lab Led with Bloc...
# 2      2017-11-09  Ethereum cryptocurrency value dropped due to w...
# 9      2017-11-09  There were more than 26,000 new blockchain pro...
# 10     2017-11-09  'Irrational exuberance' in ICOs but the tech i...
# 11     2017-11-09  Transparent Transactions: How Blockchain Payme...
# ...           ...                                                ...
# 156567 2024-08-11  Avalanche Price Prediction 2024-30: A Good Inv...
# 156569 2024-08-11  Monero Price Prediction 2024-2030: A Good Inve...
# 156570 2024-08-11  Could Bitcoin Crash? Celsius Slaps Tether with...
# 156572 2024-08-11  Best Top 5 Crypto to Buy (Short List) / X100 M...
# 156573 2024-08-11  GrabPay warns users not to buy cryptocurrency ...
#
#                   Publisher  D_VADER_Score  D_VADER_Sent  D_FINBERT_ConScore  \
# ...

# %%
final_data["2017-11-09":"2024-04-01"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2336 entries, 2017-11-09 to 2024-04-01
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   D_VADER_AvgScr_In        2336 non-null   float64
#  1   D_VADER_Sent_AvgIn       2336 non-null   int64
#  2   D_VADER_AvgScr_Ex        2336 non-null   float64
#  3   D_VADER_Sent_AvgEx       2336 non-null   int64
#  4   D_FINBERT_AvgScr_In      2336 non-null   float64
#  5   D_FINBERT_Sent_AvgIn     2336 non-null   int64
#  6   D_FINBERT_AvgScr_Ex      2316 non-null   float64
#  7   D_FINBERT_Sent_AvgEx     2336 non-null   int64
#  8   D_CRYPTOBERT_AvgScr_In   2336 non-null   float64
#  9   D_CRYPTOBERT_Sent_AvgIn  2336 non-null   int64
#  10  D_CRYPTOBERT_AvgScr_Ex   2331 non-null   float64
#  11  D_CRYPTOBERT_Sent_AvgEx  2336 non-null   int64
# dtypes: float64(6), int64(6)
# memory usage: 237.2 KB

# %%
dropped_neutrals = sentiment_data.drop(sentiment_data[sentiment_data["D_VADER_Sent"] == 0].index)

# %%
dropped_neutrals = sentiment_data.drop(sentiment_data[sentiment_data["D_VADER_Sent"] == 0].index)

# %%
index = sentiment_data[sentiment_data["D_VADER_Sent"] == 0].index

# %%
dropped_neutrals = sentiment_data

# %%
dropped_neutrals.drop(index=dropped_neutrals[dropped_neutrals["D_VADER_Sent"] == 0].index)
# Out:
# Empty DataFrame
# Columns: [News Headline, Publisher, D_VADER_Score, D_VADER_Sent, D_FINBERT_ConScore, D_FINBERT_Sent, D_CRYPTOBERT_ConScore, D_CRYPTOBERT_Sent]
# Index: []

# %%
final_data
# Out:
#             D_VADER_AvgScr_In  D_VADER_Sent_AvgIn  D_VADER_AvgScr_Ex  \
# Date
# 2017-11-09           0.082633                   1           0.202827
# 2017-11-10           0.189088                   1           0.267875
# 2017-11-11           0.065342                   1           0.112014
# 2017-11-12           0.037093                   0           0.088433
# 2017-11-13           0.036083                   0           0.078931
# ...                       ...                 ...                ...
# 2024-08-07           0.051544                   1           0.105041
# 2024-08-08           0.042091                   0           0.080019
# 2024-08-09           0.039904                   0           0.087151
# 2024-08-10           0.057555                   1           0.102567
# 2024-08-11           0.100751                   1           0.180269
#
#             D_VADER_Sent_AvgEx  D_FINBERT_AvgScr_In  D_FINBERT_Sent_AvgIn  \
# Date
# ...
