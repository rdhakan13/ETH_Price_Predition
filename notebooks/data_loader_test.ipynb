# %%
import pandas as pd
from src.common.utils import get_root_directory
from src.preprocessing.data_loader import DataLoader

# %%
root_dir = get_root_directory()
DL = DataLoader(root_dir=root_dir)

# %%
DL.load_data()

# %%
DL.merge_selected_data(selected_data=['BTC','LTC','sentiment_analysis'])
DL.final_data.columns
# Out:
# ...
# Pandas Apply:   0%|          | 0/2468 [00:00<?, ?it/s]
# Index(['ETH_D_AvgPrc', 'ETH_D_PrcDir', 'ETH_YF_Op', 'ETH_YF_Hi', 'ETH_YF_Lo',
#        'ETH_YF_Cls', 'ETH_YF_Vol', 'ETH_ES_AvgTransFee', 'ETH_ES_AvgGasPrc',
#        'ETH_ES_BlkCnt', 'ETH_ES_BlkSz', 'ETH_ES_BlkTm', 'ETH_ES_ActAdd',
#        'ETH_ES_DepCon', 'ETH_ES_GasLmt', 'ETH_ES_GasUsd', 'ETH_ES_VerCon',
#        'ETH_OL_MktCap', 'ETH_OL_NewAdd', 'ETH_OL_ChnTrans', 'ETH_OL_ChnVol',
#        'BTC_D_AvgPrc', 'BTC_YF_Op', 'BTC_YF_Hi', 'BTC_YF_Lo', 'BTC_YF_Cls',
#        'BTC_YF_Vol', 'BTC_OL_MktCap', 'BTC_OL_BlkSz', 'BTC_OL_AvgComPwr',
#        'BTC_OL_AvgTransFee', 'BTC_OL_MinDif', 'BTC_OL_ActAdd', 'BTC_OL_NewAdd',
#        'BTC_OL_ChnTrans', 'BTC_OL_ChnVol', 'BTC_BIC_HshRt', 'LTC_D_AvgPrc',
#        'LTC_YF_Op', 'LTC_YF_Hi', 'LTC_YF_Lo', 'LTC_YF_Cls', 'LTC_YF_Vol',
#        'LTC_OL_MktCap', 'LTC_OL_BlkSz', 'LTC_OL_AvgComPwr',
#        'LTC_OL_AvgTransFee', 'LTC_OL_MinDif', 'LTC_OL_ActAdd', 'LTC_OL_NewAdd',
# ...

# %%
DL.final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2335 entries, 2017-11-10 to 2024-04-01
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ETH_D_AvgPrc        2335 non-null   float64
#  1   ETH_D_PrcDir        2335 non-null   float64
#  2   ETH_YF_Op           2335 non-null   float64
#  3   ETH_YF_Hi           2335 non-null   float64
#  4   ETH_YF_Lo           2335 non-null   float64
#  5   ETH_YF_Cls          2335 non-null   float64
#  6   ETH_YF_Vol          2335 non-null   int64
#  7   ETH_ES_AvgTransFee  2335 non-null   float64
#  8   ETH_ES_AvgGasPrc    2335 non-null   int64
#  9   ETH_ES_BlkCnt       2335 non-null   int64
#  10  ETH_ES_BlkSz        2335 non-null   int64
#  11  ETH_ES_BlkTm        2335 non-null   float64
#  12  ETH_ES_ActAdd       2335 non-null   int64
#  13  ETH_ES_DepCon       2335 non-null   int64
#  14  ETH_ES_GasLmt       2335 non-null   int64
# ...

# %%
DL.merge_selected_data(selected_data=["BTC","LTC","sentiment_analysis"])
# Out:
# ...
# Pandas Apply:   0%|          | 0/2468 [00:00<?, ?it/s]

# %%
DL.set_time_range(start_date=None, end_date=None)
# Out:
# start_date is before the earliest date in the dataset, setting to the earliest date.
# end_date is after the latest date in the dataset, setting to the latest date.

# %%
DL.final_data.columns
# Out:
# Index(['ETH_D_AvgPrc', 'ETH_D_PrcDir', 'ETH_YF_Op', 'ETH_YF_Hi', 'ETH_YF_Lo',
#        'ETH_YF_Cls', 'ETH_YF_Vol', 'ETH_ES_AvgTransFee', 'ETH_ES_AvgGasPrc',
#        'ETH_ES_BlkCnt', 'ETH_ES_BlkSz', 'ETH_ES_BlkTm', 'ETH_ES_ActAdd',
#        'ETH_ES_DepCon', 'ETH_ES_GasLmt', 'ETH_ES_GasUsd', 'ETH_ES_VerCon',
#        'ETH_OL_MktCap', 'ETH_OL_NewAdd', 'ETH_OL_ChnTrans', 'ETH_OL_ChnVol',
#        'BTC_D_AvgPrc', 'BTC_YF_Op', 'BTC_YF_Hi', 'BTC_YF_Lo', 'BTC_YF_Cls',
#        'BTC_YF_Vol', 'BTC_OL_MktCap', 'BTC_OL_BlkSz', 'BTC_OL_AvgComPwr',
#        'BTC_OL_AvgTransFee', 'BTC_OL_MinDif', 'BTC_OL_ActAdd', 'BTC_OL_NewAdd',
#        'BTC_OL_ChnTrans', 'BTC_OL_ChnVol', 'BTC_BIC_HshRt', 'LTC_D_AvgPrc',
#        'LTC_YF_Op', 'LTC_YF_Hi', 'LTC_YF_Lo', 'LTC_YF_Cls', 'LTC_YF_Vol',
#        'LTC_OL_MktCap', 'LTC_OL_BlkSz', 'LTC_OL_AvgComPwr',
#        'LTC_OL_AvgTransFee', 'LTC_OL_MinDif', 'LTC_OL_ActAdd', 'LTC_OL_NewAdd',
#        'LTC_OL_ChnTrans', 'LTC_BIC_HshRt', 'D_VADER_AvgScr_In',
# ...

# %%
DL.final_data
# Out:
#             ETH_D_AvgPrc  ETH_D_PrcDir    ETH_YF_Op    ETH_YF_Hi    ETH_YF_Lo  \
# Date
# 2017-11-10    309.795990          -1.0   320.670990   324.717987   294.541992
# 2017-11-11    307.727997          -1.0   298.585999   319.453003   298.191986
# 2017-11-12    310.066002           1.0   314.690002   319.153015   298.513000
# 2017-11-13    314.795250           1.0   307.024994   328.415009   307.024994
# 2017-11-14    327.833504           1.0   316.763000   340.177002   316.763000
# ...                  ...           ...          ...          ...          ...
# 2024-03-28   3534.136902          -1.0  3500.216064  3609.705322  3465.332275
# 2024-03-29   3533.061218          -1.0  3561.011719  3583.701416  3475.725586
# 2024-03-30   3518.939636          -1.0  3511.827637  3566.084473  3489.902100
# 2024-03-31   3579.567444           1.0  3507.951660  3655.218994  3507.242676
# 2024-04-01   3554.918518          -1.0  3647.819580  3648.129150  3418.695312
#
# ...

# %%
DL.lag_features(exclude_cols=["ETH_D_AvgPrc"], lag=1)

# %%
DL.final_data
# Out:
#             ETH_D_AvgPrc  ETH_D_PrcDir    ETH_YF_Op    ETH_YF_Hi    ETH_YF_Lo  \
# Date
# 2017-11-11    307.727997          -1.0   320.670990   324.717987   294.541992
# 2017-11-12    310.066002          -1.0   298.585999   319.453003   298.191986
# 2017-11-13    314.795250           1.0   314.690002   319.153015   298.513000
# 2017-11-14    327.833504           1.0   307.024994   328.415009   307.024994
# 2017-11-15    335.511490           1.0   316.763000   340.177002   316.763000
# ...                  ...           ...          ...          ...          ...
# 2024-03-28   3534.136902          -1.0  3587.313721  3664.383057  3460.393555
# 2024-03-29   3533.061218          -1.0  3500.216064  3609.705322  3465.332275
# 2024-03-30   3518.939636          -1.0  3561.011719  3583.701416  3475.725586
# 2024-03-31   3579.567444          -1.0  3511.827637  3566.084473  3489.902100
# 2024-04-01   3554.918518           1.0  3507.951660  3655.218994  3507.242676
#
# ...

# %%
DL.select_features(features=["ETH_D_AvgPrc"])

# %%
DL.final_data
# Out:
#             ETH_D_AvgPrc
# Date
# 2017-11-11    307.727997
# 2017-11-12    310.066002
# 2017-11-13    314.795250
# 2017-11-14    327.833504
# 2017-11-15    335.511490
# ...                  ...
# 2024-03-28   3534.136902
# 2024-03-29   3533.061218
# 2024-03-30   3518.939636
# 2024-03-31   3579.567444
# 2024-04-01   3554.918518
#
# [2334 rows x 1 columns]

# %%
train, test = DL.data_split(split_type="test_train", split_size=0.2)

# %%
train, val = DL.data_split(split_type="train_val", split_size=0.2)

# %%
train.index.min()
# Out:
# Timestamp('2017-11-11 00:00:00')

# %%
train.index.max()
# Out:
# Timestamp('2021-12-14 00:00:00')

# %%
val.index.min()
# Out:
# Timestamp('2021-12-15 00:00:00')

# %%
val.index.max()
# Out:
# Timestamp('2022-12-22 00:00:00')

# %%
test.index.max()
# Out:
# Timestamp('2024-04-01 00:00:00')

# %%
test.index.min()
# Out:
# Timestamp('2022-12-23 00:00:00')
