# %%
import pandas as pd
from src.common.utils import get_root_directory
from src.preprocessing.data_loader import DataLoader

# %%
root_dir = get_root_directory()
DL = DataLoader(root_dir=root_dir)

# %%
DL.load_data()

# %%
DL.final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2336 entries, 2017-11-09 to 2024-04-01
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ETH_YF_Op           2336 non-null   float64
#  1   ETH_YF_Hi           2336 non-null   float64
#  2   ETH_YF_Lo           2336 non-null   float64
#  3   ETH_YF_Cls          2336 non-null   float64
#  4   ETH_YF_Vol          2336 non-null   int64
#  5   ETH_ES_AvgTransFee  2336 non-null   float64
#  6   ETH_ES_AvgGasPrc    2336 non-null   int64
#  7   ETH_ES_BlkCnt       2336 non-null   int64
#  8   ETH_ES_BlkSz        2336 non-null   int64
#  9   ETH_ES_BlkTm        2336 non-null   float64
#  10  ETH_ES_ActAdd       2336 non-null   int64
#  11  ETH_ES_DepCon       2336 non-null   int64
#  12  ETH_ES_GasLmt       2336 non-null   int64
#  13  ETH_ES_GasUsd       2336 non-null   int64
#  14  ETH_ES_VerCon       2336 non-null   int64
# ...

# %%
DL.merge_selected_data(selected_data=["BTC"])

# %%
DL.merge_selected_data(selected_data=["sentiment_analysis"])
# Out:
# ...
# Pandas Apply:   0%|          | 0/2468 [00:00<?, ?it/s]

# %%
DL.set_time_range(start_date="2017-11-09", end_date="2024-04-01")

# %%
DL.final_data.columns
# Out:
# Index(['ETH_YF_Op', 'ETH_YF_Hi', 'ETH_YF_Lo', 'ETH_YF_Cls', 'ETH_YF_Vol',
#        'ETH_ES_AvgTransFee', 'ETH_ES_AvgGasPrc', 'ETH_ES_BlkCnt',
#        'ETH_ES_BlkSz', 'ETH_ES_BlkTm', 'ETH_ES_ActAdd', 'ETH_ES_DepCon',
#        'ETH_ES_GasLmt', 'ETH_ES_GasUsd', 'ETH_ES_VerCon', 'ETH_OL_MktCap',
#        'ETH_OL_NewAdd', 'ETH_OL_ChnTrans', 'ETH_OL_ChnVol', 'ETH_D_AvgPrc',
#        'BTC_YF_Op', 'BTC_YF_Hi', 'BTC_YF_Lo', 'BTC_YF_Cls', 'BTC_YF_Vol',
#        'BTC_OL_MktCap', 'BTC_OL_BlkSz', 'BTC_OL_AvgComPwr',
#        'BTC_OL_AvgTransFee', 'BTC_OL_MinDif', 'BTC_OL_ActAdd', 'BTC_OL_NewAdd',
#        'BTC_OL_ChnTrans', 'BTC_OL_ChnVol', 'BTC_BIC_HshRt', 'BTC_D_AvgPrc',
#        'D_VADER_AvgScr_In', 'D_VADER_Sent_AvgIn', 'D_VADER_AvgScr_Ex',
#        'D_VADER_Sent_AvgEx', 'D_FINBERT_AvgScr_In', 'D_FINBERT_Sent_AvgIn',
#        'D_FINBERT_AvgScr_Ex', 'D_FINBERT_Sent_AvgEx', 'D_CRYPTOBERT_AvgScr_In',
#        'D_CRYPTOBERT_Sent_AvgIn', 'D_CRYPTOBERT_AvgScr_Ex',
# ...

# %%
DL.final_data
# Out:
#               ETH_YF_Op    ETH_YF_Hi    ETH_YF_Lo   ETH_YF_Cls    ETH_YF_Vol  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003  8.932500e+08
# 2017-11-10   320.670990   324.717987   294.541992   299.252991  8.859860e+08
# 2017-11-11   298.585999   319.453003   298.191986   314.681000  8.423010e+08
# 2017-11-12   314.690002   319.153015   298.513000   307.907990  1.613480e+09
# 2017-11-13   307.024994   328.415009   307.024994   316.716003  1.041890e+09
# ...                 ...          ...          ...          ...           ...
# 2024-03-28  3500.216064  3609.705322  3465.332275  3561.293945  1.641967e+10
# 2024-03-29  3561.011719  3583.701416  3475.725586  3511.806152  1.271270e+10
# 2024-03-30  3511.827637  3566.084473  3489.902100  3507.944336  9.389067e+09
# 2024-03-31  3507.951660  3655.218994  3507.242676  3647.856445  1.049988e+10
# 2024-04-01  3647.819580  3648.129150  3418.695312  3505.030029  1.600210e+10
#
# ...

# %%
DL.lag_features(exclude_cols=["ETH_D_AvgPrc", "ETH_YF_Op"], lag=1)

# %%
DL.final_data
# Out:
#               ETH_YF_Op    ETH_YF_Hi    ETH_YF_Lo   ETH_YF_Cls    ETH_YF_Vol  \
# Date
# 2017-11-11   320.670990   329.451996   307.056000   320.884003  8.932500e+08
# 2017-11-12   298.585999   324.717987   294.541992   299.252991  8.859860e+08
# 2017-11-13   314.690002   319.453003   298.191986   314.681000  8.423010e+08
# 2017-11-14   307.024994   319.153015   298.513000   307.907990  1.613480e+09
# 2017-11-15   316.763000   328.415009   307.024994   316.716003  1.041890e+09
# ...                 ...          ...          ...          ...           ...
# 2024-03-28  3587.313721  3678.789795  3545.428711  3587.504883  1.850555e+10
# 2024-03-29  3500.216064  3664.383057  3460.393555  3500.115234  1.875308e+10
# 2024-03-30  3561.011719  3609.705322  3465.332275  3561.293945  1.641967e+10
# 2024-03-31  3511.827637  3583.701416  3475.725586  3511.806152  1.271270e+10
# 2024-04-01  3507.951660  3566.084473  3489.902100  3507.944336  9.389067e+09
#
# ...
